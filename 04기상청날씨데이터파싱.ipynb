# %% [markdown]
# ### 기상청 날씨 데이터 파싱
# * BeautifulSoup 객체의 find(), find_all() 함수 사용하여 파싱하기
# * 파싱한 데이터를 dict, list에 저장하기
# * json file로 저장하기

# %%
import requests
from bs4 import BeautifulSoup

url = 'http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp'

res = requests.get(url)
if res.ok:
    soup = BeautifulSoup(res.text, 'html.parser')
    
    title_tag = soup.find('title')
    print(type(title_tag), title_tag, title_tag.text)
    
    title_all_tag = soup.find_all('title')
    #print(type(title_all_tag), title_all_tag)
    for title in title_all_tag:
        print(type(title.string), type(title.text))
        #print(title.string, title.text)

    location_tag = soup.find('location', attrs={'wl_ver':3})
    print('==find() ', type(location_tag))

    location_tag2 = soup.select_one("location[wl_ver='3']")
    print('==select_one() ',type(location_tag2))

    loc_tag_all = soup.findAll('location', attrs={'wl_ver':3})
    print('==find_all() ', type(loc_tag_all))

    loc_tag_all2 = soup.select("location[wl_ver='3']")
    print('==select() ', type(loc_tag_all2))
# Out:
# <class 'bs4.element.Tag'> <title>기상청 육상 중기예보</title> 기상청 육상 중기예보
# <class 'bs4.element.NavigableString'> <class 'str'>
# <class 'bs4.element.NavigableString'> <class 'str'>
# <class 'bs4.element.NavigableString'> <class 'str'>
# ==find()  <class 'bs4.element.Tag'>
# ==select_one()  <class 'bs4.element.Tag'>
# ==find_all()  <class 'bs4.element.ResultSet'>
# ==select()  <class 'bs4.element.ResultSet'>

# %%
'''
<location wl_ver="3">
    <province>서울ㆍ인천ㆍ경기도</province>
    <city>서울</city>
    <data>
        <mode>A02</mode>
        <tmEf>2022-01-31 00:00</tmEf>
        <wf>맑음</wf>
        <tmn>-6</tmn>
        <tmx>4</tmx>
        <reliability/>
        <rnSt>0</rnSt>
    </data>
    <data>
        <mode>A02</mode>
        <tmEf>2022-01-31 12:00</tmEf>
        <wf>구름많음</wf>
        <tmn>-6</tmn>
        <tmx>4</tmx>
        <reliability/>
        <rnSt>40</rnSt>
    </data>
</location>
{
  “province”:”서울ㆍ인천ㆍ경기도”,
   “city”:”서울”,
   “datas”:[{“mode”:”A02”,”tmEf”:”2022-01-31 00:00”,”wf”:”맑음”},
          {“mode”:”A02”,”tmEf”:”2022-01-31 12:00”,”wf”:”구름많음”}]
}

'''
import requests
from bs4 import BeautifulSoup
url = 'http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp'

res = requests.get(url)
if res.ok:
    soup = BeautifulSoup(res.text, 'html.parser')
    location_tag = soup.find('location', attrs={'wl_ver':3})
    location_dict = {} #dict()

    location_dict['province'] = location_tag.find('province').text
    location_dict['city'] = location_tag.find('city').text

    data_tags = location_tag.find_all('data')
    data_list = []
    for data_tag in data_tags:
        data_dict = {}
        data_dict['mode'] = data_tag.find('mode').text
        data_dict['tmEf'] = data_tag.find('tmef').text
        data_dict['wf'] = data_tag.find('wf').text
        data_dict['tmn'] = data_tag.find('tmn').text
        data_dict['tmx'] = data_tag.find('tmx').text
        data_list.append(data_dict)

    location_dict['datas'] = data_list
    print(location_dict)
# Out:
# {'province': '서울ㆍ인천ㆍ경기도', 'city': '서울', 'datas': [{'mode': 'A02', 'tmEf': '2022-01-31 00:00', 'wf': '맑음', 'tmn': '-6', 'tmx': '4'}, {'mode': 'A02', 'tmEf': '2022-01-31 12:00', 'wf': '구름많음', 'tmn': '-6', 'tmx': '4'}, {'mode': 'A02', 'tmEf': '2022-02-01 00:00', 'wf': '구름많고 눈', 'tmn': '-2', 'tmx': '2'}, {'mode': 'A02', 'tmEf': '2022-02-01 12:00', 'wf': '구름많고 눈', 'tmn': '-2', 'tmx': '2'}, {'mode': 'A02', 'tmEf': '2022-02-02 00:00', 'wf': '맑음', 'tmn': '-6', 'tmx': '1'}, {'mode': 'A02', 'tmEf': '2022-02-02 12:00', 'wf': '맑음', 'tmn': '-6', 'tmx': '1'}, {'mode': 'A02', 'tmEf': '2022-02-03 00:00', 'wf': '맑음', 'tmn': '-7', 'tmx': '1'}, {'mode': 'A02', 'tmEf': '2022-02-03 12:00', 'wf': '맑음', 'tmn': '-7', 'tmx': '1'}, {'mode': 'A02', 'tmEf': '2022-02-04 00:00', 'wf': '맑음', 'tmn': '-7', 'tmx': '1'}, {'mode': 'A02', 'tmEf': '2022-02-04 12:00', 'wf': '맑음', 'tmn': '-7', 'tmx': '1'}, {'mode': 'A01', 'tmEf': '2022-02-05 00:00', 'wf': '맑음', 'tmn': '-7', 'tmx': '1'}, {'mode': 'A01', 'tmEf': '2022-02-06 00:00', 'wf': '맑음', 'tmn': '-6', 'tmx': '2'}, {'mode': 'A01', 'tmEf': '2022-02-07 00:00', 'wf': '맑음', 'tmn': '-5', 'tmx': '4'}]}

# %% [markdown]
# ### 전국날씨데이터 파싱

# %%
import requests
from bs4 import BeautifulSoup
url = 'http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp'

res = requests.get(url)
if res.ok:
    soup = BeautifulSoup(res.text, 'html.parser')
    location_tags = soup.find_all('location', attrs={'wl_ver':3})
    print(len(location_tags))
    
    location_list = []
    for location_tag in location_tags:
        location_dict = {}
        location_dict['province'] = location_tag.find('province').text
        location_dict['city'] = location_tag.find('city').text

        data_tags = location_tag.find_all('data')
        print(len(data_tags))
        data_list = []
        for data_tag in data_tags:
            data_dict = {}
            data_dict['mode'] = data_tag.find('mode').text
            data_dict['tmEf'] = data_tag.find('tmef').text
            data_dict['wf'] = data_tag.find('wf').text
            data_dict['tmn'] = data_tag.find('tmn').text
            data_dict['tmx'] = data_tag.find('tmx').text
            data_list.append(data_dict)

        location_dict['datas'] = data_list
        location_list.append(location_dict)

print(len(location_list))
#print(location_list)
# Out:
# 41
# 41

# %% [markdown]
# ### location_list 를 json 파일로 저장하기

# %%
import json

# json file 저장
with open('data\\weather.json','w') as file:
    json.dump(location_list, file)

# %%
# json file 읽기
with open('data\\weather.json','r', encoding='utf-8') as file:
    content = file.read()
    json_content = json.loads(content)

print(json_content)
# Out:
# [{'province': '서울ㆍ인천ㆍ경기도', 'city': '서울', 'datas': [{'mode': 'A02', 'tmEf': '2022-01-31 00:00', 'wf': '맑음', 'tmn': '-6', 'tmx': '4'}, {'mode': 'A02', 'tmEf': '2022-01-31 12:00', 'wf': '구름많음', 'tmn': '-6', 'tmx': '4'}, {'mode': 'A02', 'tmEf': '2022-02-01 00:00', 'wf': '구름많고 눈', 'tmn': '-2', 'tmx': '2'}, {'mode': 'A02', 'tmEf': '2022-02-01 12:00', 'wf': '구름많고 눈', 'tmn': '-2', 'tmx': '2'}, {'mode': 'A02', 'tmEf': '2022-02-02 00:00', 'wf': '맑음', 'tmn': '-6', 'tmx': '1'}, {'mode': 'A02', 'tmEf': '2022-02-02 12:00', 'wf': '맑음', 'tmn': '-6', 'tmx': '1'}, {'mode': 'A02', 'tmEf': '2022-02-03 00:00', 'wf': '맑음', 'tmn': '-7', 'tmx': '1'}, {'mode': 'A02', 'tmEf': '2022-02-03 12:00', 'wf': '맑음', 'tmn': '-7', 'tmx': '1'}, {'mode': 'A02', 'tmEf': '2022-02-04 00:00', 'wf': '맑음', 'tmn': '-7', 'tmx': '1'}, {'mode': 'A02', 'tmEf': '2022-02-04 12:00', 'wf': '맑음', 'tmn': '-7', 'tmx': '1'}, {'mode': 'A01', 'tmEf': '2022-02-05 00:00', 'wf': '맑음', 'tmn': '-7', 'tmx': '1'}, {'mode': 'A01', 'tmEf': '2022-02-06 00:00', 'wf': '맑음', 'tmn': '-6', 'tmx': '2'}, {'mode': 'A01', 'tmEf': '2022-02-07 00:00', 'wf': '맑음', 'tmn': '-5', 'tmx': '4'}]}, {'province': '서울ㆍ인천ㆍ경기도', 'city': '인천', 'datas': [{'mode': 'A02', 'tmEf': '2022-01-31 00:00', 'wf': '맑음', 'tmn': '-5', 'tmx': '3'}, {'mode': 'A02', 'tmEf': '2022-01-31 12:00', 'wf': '구름많음', 'tmn': '-5', 'tmx': '3'}, {'mode': 'A02', 'tmEf': '2022-02-01 00:00', 'wf': '구름많고 눈', 'tmn': '-1', 'tmx': '2'}, {'mode': 'A02', 'tmEf': '2022-02-01 12:00', 'wf': '구름많고 눈', 'tmn': '-1', 'tmx': '2'}, {'mode': 'A02', 'tmEf': '2022-02-02 00:00', 'wf': '맑음', 'tmn': '-5', 'tmx': '0'}, {'mode': 'A02', 'tmEf': '2022-02-02 12:00', 'wf': '맑음', 'tmn': '-5', 'tmx': '0'}, {'mode': 'A02', 'tmEf': '2022-02-03 00:00', 'wf': '맑음', 'tmn': '-6', 'tmx': '0'}, {'mode': 'A02', 'tmEf': '2022-02-03 12:00', 'wf': '맑음', 'tmn': '-6', 'tmx': '0'}, {'mode': 'A02', 'tmEf': '2022-02-04 00:00', 'wf': '맑음', 'tmn': '-6', 'tmx': '0'}, {'mode': 'A02', 'tmEf': '2022-02-04 12:00', 'wf': '맑음', 'tmn': '-6', 'tmx': '0'}, {'mode': 'A01', 'tmEf': '2022-02-05 00:00', 'wf': '맑음', 'tmn': '-6', 'tmx': '0'}, {'mode': 'A01', 'tmEf': '2022-02-06 00:00', 'wf': '맑음', 'tmn': '-5', 'tmx': '1'}, {'mode': 'A01', 'tmEf': '2022-02-07 00:00', 'wf': '맑음', 'tmn': '-4', 'tmx': '3'}]}, {'province': '서울ㆍ인천ㆍ경기도', 'city': '수원', 'datas': [{'mode': 'A02', 'tmEf': '2022-01-31 00:00', 'wf': '맑음', 'tmn': '-7', 'tmx': '5'}, {'mode': 'A02', 'tmEf': '2022-01-31 12:00', 'wf': '구름많음', 'tmn': '-7', 'tmx': '5'}, {'mode': 'A02', 'tmEf': '2022-02-01 00:00', 'wf': '구름많고 눈', 'tmn': '-3', 'tmx': '2'}, {'mode': 'A02', 'tmEf': '2022-02-01 12:00', 'wf': '구름많고 눈', 'tmn': '-3', 'tmx': '2'}, {'mode': 'A02', 'tmEf': '2022-02-02 00:00', 'wf': '맑음', 'tmn': '-7', 'tmx': '2'}, {'mode': 'A02', 'tmEf': '2022-02-02 12:00', 'wf': '맑음', 'tmn': '-7', 'tmx': '2'}, {'mode': 'A02', 'tmEf': '2022-02-03 00:00', 'wf': '맑음', 'tmn': '-7', 'tmx': '2'}, {'mode': 'A02', 'tmEf': '2022-02-03 12:00', 'wf': '맑음', 'tmn': '-7', 'tmx': '2'}, {'mode': 'A02', 'tmEf': '2022-02-04 00:00', 'wf': '맑음', 'tmn': '-8', 'tmx': '1'}, {'mode': 'A02', 'tmEf': '2022-02-04 12:00', 'wf': '맑음', 'tmn': '-8', 'tmx': '1'}, {'mode': 'A01', 'tmEf': '2022-02-05 00:00', 'wf': '맑음', 'tmn': '-7', 'tmx': '1'}, {'mode': 'A01', 'tmEf': '2022-02-06 00:00', 'wf': '맑음', 'tmn': '-7', 'tmx': '2'}, {'mode': 'A01', 'tmEf': '2022-02-07 00:00', 'wf': '맑음', 'tmn': '-6', 'tmx': '5'}]}, {'province': '서울ㆍ인천ㆍ경기도', 'city': '파주', 'datas': [{'mode': 'A02', 'tmEf': '2022-01-31 00:00', 'wf': '맑음', 'tmn': '-11', 'tmx': '4'}, {'mode': 'A02', 'tmEf': '2022-01-31 12:00', 'wf': '구름많음', 'tmn': '-11', 'tmx': '4'}, {'mode': 'A02', 'tmEf': '2022-02-01 00:00', 'wf': '구름많고 눈', 'tmn': '-6', 'tmx': '2'}, {'mode': 'A02', 'tmEf': '2022-02-01 12:00', 'wf': '구름많고 눈', 'tmn': '-6', 'tmx': '2'}, {'mode': 'A02', 'tmEf': '2022-02-02 00:00', 'wf': '맑음', 'tmn': '-9', 'tmx': '1'}, {'mode': 'A02', 'tmEf': '2022-02-02 12:00', 'wf': '맑음', 'tmn': '-9', 'tmx': '1'}, {'mode': 'A02', 'tmEf': '2022-02-03 00:00', 'wf': '맑음', 'tmn' ...
